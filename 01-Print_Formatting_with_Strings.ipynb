# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/test/blob/main/01-Print_Formatting_with_Strings.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formatage de chaîneLe formatage de chaîne vous permet d'injecter des éléments dans une chaîne plutôt que d'essayer d'enchaîner des éléments à l'aide de virgules ou d'une concaténation de chaînes. Pour une comparaison rapide, considérez:joueur = 'Thomas'points = 33'Hier soir, '+joueur+' a marqué '+str(points)+' points.' # concaténationf'La nuit dernière, {player} a marqué {points} points.' # formatage de chaîneIl existe trois façons d'effectuer le formatage des chaînes.* La méthode la plus ancienne implique des espaces réservés utilisant le caractère modulo `%`.* Une technique améliorée utilise la méthode de chaîne `.format()`.* La méthode la plus récente, introduite avec Python 3.6, utilise des littéraux de chaîne formatés, appelés *f-strings*.Puisque vous rencontrerez probablement les trois versions dans le code de quelqu'un d'autre, nous décrivons chacune d'elles ici.

# %% [markdown]
# ## Formatage avec des espaces réservésVous pouvez utiliser <code>%s</code> pour injecter des chaînes dans vos instructions d'impression. Le modulo `%` est appelé "opérateur de formatage de chaîne".

# %%
print("I'm going to inject %s here." %'something')
# Out:
# I'm going to inject something here.

# %% [markdown]
# Vous pouvez passer plusieurs éléments en les plaçant dans un tuple après l'opérateur `%`.

# %%
print("I'm going to inject %s text here, and %s text here." %('some','more'))
# Out:
# I'm going to inject some text here, and more text here.

# %% [markdown]
# Vous pouvez également transmettre des noms de variables :

# %%
x, y = 'some', 'more'
print("I'm going to inject %s text here, and %s text here."%(x,y))
# Out:
# I'm going to inject some text here, and more text here.

# %% [markdown]
# ### Méthodes de conversion de format.Il convient de noter que deux méthodes <code>%s</code> et <code>%r</code> convertissent tout objet python en une chaîne en utilisant deux méthodes distinctes : `str()` et `repr()`. Nous en apprendrons plus sur ces fonctions plus tard dans le cours, mais vous devez noter que `%r` et `repr()` fournissent la *représentation sous forme de chaîne* de l'objet, y compris les guillemets et tous les caractères d'échappement.

# %%
print('He said his name was %s.' %'Fred')
print('He said his name was %r.' %'Fred')
# Out:
# He said his name was Fred.
# He said his name was 'Fred'.

# %% [markdown]
# Comme autre exemple, `\t` insère une tabulation dans une chaîne.

# %%
print('I once caught a fish %s.' %'this \tbig')
print('I once caught a fish %r.' %'this \tbig')
# Out:
# I once caught a fish this 	big.
# I once caught a fish 'this \tbig'.

# %% [markdown]
# L'opérateur `%s` convertit tout ce qu'il voit en une chaîne, y compris les entiers et les flottants. L'opérateur `%d` convertit d'abord les nombres en nombres entiers, sans arrondi. Notez la différence ci-dessous :

# %%
print('I wrote %s programs today.' %3.75)
print('I wrote %d programs today.' %3.75)
# Out:
# I wrote 3.75 programs today.
# I wrote 3 programs today.

# %% [markdown]
# ### Remplissage et précision des nombres à virgule flottanteLes nombres à virgule flottante utilisent le format <code>%5.2f</code>. Ici, <code>5</code> serait le nombre minimum de caractères que la chaîne devrait contenir ; ceux-ci peuvent être complétés par des espaces blancs si le nombre entier n'a pas autant de chiffres. À côté de cela, <code>.2f</code> représente le nombre de nombres à afficher après la virgule. Voyons quelques exemples :

# %%
print('Floating point numbers: %5.2f' %(13.144))
# Out:
# Floating point numbers: 13.14

# %%
print('Floating point numbers: %1.0f' %(13.144))
# Out:
# Floating point numbers: 13

# %%
print('Floating point numbers: %1.5f' %(13.144))
# Out:
# Floating point numbers: 13.14400

# %%
print('Floating point numbers: %10.2f' %(13.144))
# Out:
# Floating point numbers:      13.14

# %%
print('Floating point numbers: %25.2f' %(13.144))
# Out:
# Floating point numbers:                     13.14

# %% [markdown]
# Pour plus d'informations sur le formatage des chaînes avec des espaces réservés, visitez https://docs.python.org/3/library/stdtypes.html#old-string-formatting

# %% [markdown]
# ### Formatage multipleRien n'interdit d'utiliser plus d'un outil de conversion dans la même instruction print :

# %%
print('First: %s, Second: %5.2f, Third: %r' %('hi!',3.1415,'bye!'))
# Out:
# First: hi!, Second:  3.14, Third: 'bye!'

# %% [markdown]
# ## Formatage avec la méthode `.format()`Une meilleure façon de formater des objets dans vos chaînes pour les instructions d'impression consiste à utiliser la méthode de chaîne `.format()`. La syntaxe est :'Chaîne ici {} puis aussi {}'.format('something1','something2')Par exemple:

# %%
print('This is a string with an {}'.format('insert'))
# Out:
# This is a string with an insert

# %% [markdown]
# ### La méthode .format() présente plusieurs avantages par rapport à la méthode d'espace réservé %s :

# %% [markdown]
# #### 1. Les objets insérés peuvent être appelés par position d'index :

# %%
print('The {2} {1} {0}'.format('fox','brown','quick'))
# Out:
# The quick brown fox

# %% [markdown]
# #### 2. Les objets insérés peuvent se voir attribuer des mots-clés :

# %%
print('First Object: {a}, Second Object: {b}, Third Object: {c}'.format(a=1,b='Two',c=12.3))
# Out:
# First Object: 1, Second Object: Two, Third Object: 12.3

# %% [markdown]
# #### 3. Les objets insérés peuvent être réutilisés, évitant la duplication :

# %%
print('A %s saved is a %s earned.' %('penny','penny'))
# vs.
print('A {p} saved is a {p} earned.'.format(p='penny'))
# Out:
# A penny saved is a penny earned.
# A penny saved is a penny earned.

# %% [markdown]
# ### Alignement, remplissage et précision avec `.format()`Dans les accolades, vous pouvez attribuer des longueurs de champ, des alignements gauche/droite, des paramètres d'arrondi et plus encore

# %%
print('{0:8} | {1:9}'.format('Fruit', 'Quantity'))
print('{0:8} | {1:9}'.format('Apples', 3.))
print('{0:8} | {1:9}'.format('Oranges', 10))
# Out:
# Fruit    | Quantity
# Apples   |       3.0
# Oranges  |        10

# %% [markdown]
# Par défaut, `.format()` aligne le texte à gauche, les nombres à droite. Vous pouvez passer un `<`,`^` ou `>` facultatif pour définir un alignement à gauche, au centre ou à droite :

# %%
print('{0:<8} | {1:^8} | {2:>8}'.format('Left','Center','Right'))
print('{0:<8} | {1:^8} | {2:>8}'.format(11,22,33))
# Out:
# Left     |  Center  |    Right
# 11       |    22    |       33

# %% [markdown]
# Vous pouvez faire précéder l'opérateur d'alignement d'un caractère de remplissage

# %%
print('{0:=<8} | {1:-^8} | {2:.>8}'.format('Left','Center','Right'))
print('{0:=<8} | {1:-^8} | {2:.>8}'.format(11,22,33))
# Out:
# Left==== | -Center- | ...Right
# 11====== | ---22--- | ......33

# %% [markdown]
# Les largeurs de champ et la précision flottante sont gérées de la même manière que les espaces réservés. Les deux instructions d'impression suivantes sont équivalentes :

# %%
print('This is my ten-character, two-decimal number:%10.2f' %13.579)
print('This is my ten-character, two-decimal number:{0:10.2f}'.format(13.579))
# Out:
# This is my ten-character, two-decimal number:     13.58
# This is my ten-character, two-decimal number:     13.58

# %% [markdown]
# Notez qu'il y a 5 espaces après les deux-points, et 5 caractères occupés par 13,58, pour un total de dix caractères.Pour plus d'informations sur la méthode string `.format()`, visitez https://docs.python.org/3/library/string.html#formatstrings

# %% [markdown]
# ## Littéraux de chaîne formatés (chaînes f)

# %% [markdown]
# Introduites dans Python 3.6, les f-strings offrent plusieurs avantages par rapport à l'ancienne méthode de chaîne `.format()` décrite ci-dessus. D'une part, vous pouvez introduire immédiatement des variables externes dans la chaîne plutôt que de les transmettre en tant qu'arguments via `.format(var)`.

# %%
name = 'Fred'

print(f"He said his name is {name}.")
# Out:
# He said his name is Fred.

# %% [markdown]
# Passez ` !r` pour obtenir la représentation sous forme de chaîne :

# %%
print(f"He said his name is {name!r}")
# Out:
# He said his name is 'Fred'

# %% [markdown]
# #### Le formatage flottant suit `"result : {value:{width}.{precision}}"`

# %% [markdown]
# Là où avec la méthode `.format()` vous pourriez voir `{value:10.4f}`, avec les f-strings cela peut devenir `{value:{10}.{6}}`

# %%
num = 23.45678
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
print(f"My 10 character, four decimal number is:{num:{10}.{6}}")
# Out:
# My 10 character, four decimal number is:   23.4568
# My 10 character, four decimal number is:   23.4568

# %% [markdown]
# Notez qu'avec les f-strings, *précision* fait référence au nombre total de chiffres, pas seulement à ceux qui suivent la décimale. Cela correspond plus étroitement à la notation scientifique et à l'analyse statistique. Malheureusement, les f-strings ne remplissent pas à droite de la décimale, même si la précision le permet :

# %%
num = 23.45
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
print(f"My 10 character, four decimal number is:{num:{10}.{6}}")
# Out:
# My 10 character, four decimal number is:   23.4500
# My 10 character, four decimal number is:     23.45

# %% [markdown]
# Si cela devient important, vous pouvez toujours utiliser la syntaxe de la méthode `.format()` dans une f-string :

# %%
num = 23.45
print("My 10 character, four decimal number is:{0:10.4f}".format(num))
print(f"My 10 character, four decimal number is:{num:10.4f}")
# Out:
# My 10 character, four decimal number is:   23.4500
# My 10 character, four decimal number is:   23.4500

# %% [markdown]
# Pour plus d'informations sur les littéraux de chaîne formatés, visitez https://docs.python.org/3/reference/lexical_analysis.html#f-strings
